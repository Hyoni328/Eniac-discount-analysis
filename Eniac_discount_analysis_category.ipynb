# %%
import pandas as pd

# %%
url = 'https://drive.google.com/file/d/1m1ThDDIYRTTii-rqM5SEQjJ8McidJskD/view?usp=sharing'
path = 'https://drive.google.com/uc?export=download&id='+url.split('/')[-2]
brand = pd.read_csv(path)

url = 'https://drive.google.com/file/d/1MU4ytm-xZEsTTq-jqYQM233m7szBy2dO/view?usp=sharing'
path = 'https://drive.google.com/uc?export=download&id='+url.split('/')[-2]
orderlines_qu = pd.read_csv(path)

url = 'https://drive.google.com/file/d/13hW5aRPj0zNYmStIMBxfTCu2FWSD3iKz/view?usp=sharing'
path = 'https://drive.google.com/uc?export=download&id='+url.split('/')[-2]
orders_qu = pd.read_csv(path)

url = "https://drive.google.com/file/d/1s7Lai4NSlsYjGEPg1QSOUJobNYVsZBOJ/view?usp=sharing"
path = "https://drive.google.com/uc?export=download&id="+url.split("/")[-2]
products_cl = pd.read_csv(path)

# %%
product_category_df = products_cl.copy()

# %% [markdown]
# ## Category
# - Memory & Storage
# - Smartphones: iPhone
# - Computers & Laptops: Macbook, iMac, Mac mini
# - Apple Devices: iPad, watch, airpods
# - Accessories for iPhone
# - Accessories for Computers & Laptops
# - Others

# %%
url = 'https://drive.google.com/file/d/1AAigUKwTyg794QzoMscLJOL53kYbj9EK/view?usp=sharing'
path = 'https://drive.google.com/uc?export=download&id='+url.split('/')[-2]
hyoeun_pc_df = pd.read_csv(path)

# %%
hyoeun_pc_df['category'].value_counts()
# Out:
# category
# iPhone accessories      1284
# computer                1068
# storage                 1016
# server                   969
# computer accessories     722
# smartwatch               327
# iPhone                   262
# ipad                     185
# backpack                  59
# Name: count, dtype: int64

# %% [markdown]
# ## Unified category

# %%
# Memory & Storage
m_s = product_category_df.loc[(product_category_df['category'] == 'Memory and Storage'), 'category']
new_pc_df.loc[m_s.index, 'category'] = 'Memory & Storage'

# %%
# Smartphones
smartphone = hyoeun_pc_df.loc[(hyoeun_pc_df['category'] == 'iPhone'), 'category']
new_pc_df.loc[smartphone.index, 'category'] = 'Smartphones'
new_pc_df['category'].value_counts()
# Out:
# category
#                     6576
# Memory & Storage    3154
# Smartphones          262
# Name: count, dtype: int64

# %%
# Computers & Laptops
computers = hyoeun_pc_df.loc[(hyoeun_pc_df['category'] == 'computer'), 'category']
new_pc_df.loc[computers.index, 'category'] = 'Computers & Laptops'
new_pc_df['category'].value_counts()
# Out:
# category
#                        6485
# Memory & Storage       2177
# Computers & Laptops    1068
# Smartphones             262
# Name: count, dtype: int64

# %% [markdown]
# Electronic devices
# - ipad
# - watch, airpods

# %%
ipad = hyoeun_pc_df.loc[(hyoeun_pc_df['category'] == 'ipad'), 'category']
new_pc_df.loc[ipad.index, 'category'] = 'Apple Devices'
new_pc_df['category'].value_counts()
# Out:
# category
#                        6300
# Memory & Storage       2177
# Computers & Laptops    1068
# Smartphones             262
# Apple Devices           185
# Name: count, dtype: int64

# %%
# airpods
new_pc_df.loc[(5484, 8984), 'category'] = 'Apple Devices'

# %%
#Accessories for iPhone
iph_acc = hyoeun_pc_df.loc[(hyoeun_pc_df['category'] == 'iPhone accessories'), 'category']
new_pc_df.loc[iph_acc.index, 'category'] = 'Accessories for Smartphones'
new_pc_df['category'].value_counts()
# Out:
# category
#                                5097
# Memory & Storage               2094
# Accessories for Smartphones    1284
# Computers & Laptops            1068
# Smartphones                     262
# Apple Devices                   187
# Name: count, dtype: int64

# %%
# Accessories for Computers & Laptops
com_acc = hyoeun_pc_df.loc[(hyoeun_pc_df['category'] == 'computer accessories'), 'category']
new_pc_df.loc[com_acc.index, 'category'] = 'Accessories for Computers & Laptops'

bag = hyoeun_pc_df.loc[(hyoeun_pc_df['category'] == 'backpack'), 'category']
new_pc_df.loc[bag.index, 'category'] = 'Accessories for Computers & Laptops'
new_pc_df['category'].value_counts()
# Out:
# category
#                                        4383
# Memory & Storage                       2027
# Accessories for Smartphones            1284
# Computers & Laptops                    1068
# Accessories for Computers & Laptops     781
# Smartphones                             262
# Apple Devices                           187
# Name: count, dtype: int64

# %%
com_acc2 = product_category_df.loc[(product_category_df['category'] == 'Keyboards and Mice'), 'category']
new_pc_df.loc[com_acc2.index, 'category'] = 'Accessories for Computers & Laptops'
new_pc_df['category'].value_counts()
# Out:
# category
#                                        4367
# Memory & Storage                       2027
# Accessories for Smartphones            1280
# Computers & Laptops                    1054
# Accessories for Computers & Laptops     815
# Smartphones                             262
# Apple Devices                           187
# Name: count, dtype: int64

# %%
product_category_df.loc[(product_category_df['category'] == 'Stands and Supports')] #'category']
# Out:
#             sku                                               name  \
# 0       RAI0007                  Silver Rain Design mStand Support
# 17      HGD0007       Henge Docks Docking Station MacBook Pro 13 "
# 22      JMO0014                   Just Mobile Upstand iPad support
# 37      MUV0023  Extreme Muvit iPhone and iPod BikeMount sleeve...
# 38      JMO0026        Just Mobile Lazy Couch Support Mac and iPad
# ...         ...                                                ...
# 9945  TWS0106-A  Open - Twelve South Bridge Magic Keyboard for ...
# 9955    DVI0012        Devia Grace Light iPad Case 97 "(2017) Gold
# 9956    DVI0013        Devia Grace Light iPad Case 97 "(2017) Rosa
# 9969    AP20468       Like new - Apple iPhone Black Lightning Dock
# 9987    BEL0376            Belkin Travel Support Apple Watch Black
#
#                                                    desc  price  in_stock  \
# 0          Aluminum support compatible with all MacBook  59.99         1
# ...

# %%
apple = new_pc_df.loc[(new_pc_df['name'].str.contains('apple', case=False)) & (new_pc_df['sku'].str.contains('AP', case=False)) & (new_pc_df['category'] == '')]
dock = apple.loc[apple['name'].str.contains('dock', case=False)]
new_pc_df.loc[dock.index, 'category'] = 'Accessories for Smartphones'

# %%
iph_acc2 = apple.loc[apple['name'].str.contains('iphone', case=False)]
new_pc_df.loc[iph_acc2.index, 'category'] = 'Accessories for Smartphones'

# %%
new_pc_df.loc[(new_pc_df['category'] == 'Accessories for iPhone'), 'category'] = 'Accessories for Smartphones'
new_pc_df['category'].value_counts()
# Out:
# category
#                                        4340
# Memory & Storage                       2027
# Accessories for Smartphones            1307
# Computers & Laptops                    1054
# Accessories for Computers & Laptops     815
# Smartphones                             262
# Apple Devices                           187
# Name: count, dtype: int64

# %%
new_pc_df.loc[(apple.loc[(apple['name'].str.contains('Apple charging cable', case=False))]).index, 'category'] = 'Accessories for Smartphones'
new_pc_df['category'].value_counts()
# Out:
# category
#                                        4337
# Memory & Storage                       2027
# Accessories for Smartphones            1310
# Computers & Laptops                    1054
# Accessories for Computers & Laptops     815
# Smartphones                             262
# Apple Devices                           187
# Name: count, dtype: int64

# %%
new_pc_df.loc[(new_pc_df.loc[(new_pc_df['category'] == '') & (new_pc_df['desc'].str.contains('hard drive', case=False))]).index, 'category'] = 'Memory & Storage'

# %%
new_pc_df.loc[(new_pc_df.loc[(new_pc_df['category'] == '') & (new_pc_df['desc'].str.contains('lightning', case=False))]).index, 'category'] = 'Accessories for Smartphones'

# %%
new_pc_df.loc[(new_pc_df.loc[(new_pc_df['category'] == '') & (new_pc_df['name'].str.contains('sandisk', case=False))]).index, 'category'] = 'Memory & Storage'

# %%
#olloclip
new_pc_df.loc[(new_pc_df.loc[(new_pc_df['category'] == '') & (new_pc_df['name'].str.contains('olloclip', case=False))]).index, 'category'] = 'Accessories for Smartphones'

# %%
new_pc_df.loc[(51,52), 'category'] = 'Accessories for Computers & Laptops'

# %%
new_pc_df.loc[(new_pc_df.loc[(new_pc_df['category'] == '') & (new_pc_df['name'].str.contains('cable', case=False)) & (new_pc_df['desc'].str.contains('iphone', case=False))]).index, 'category'] = 'Accessories for Smartphones'

# %%
new_pc_df.loc[
    (new_pc_df.loc[(new_pc_df['category'] == '') &
     (new_pc_df['name'].str.contains('cable', case=False)) &
                   ~(new_pc_df['desc'].str.contains('watch', case=False))]).index,
    'category'] = 'Accessories for Computers & Laptops'

# %%
new_pc_df.loc[(new_pc_df['category'] == 'Apple Devices'), 'category'] = 'Electronic Devices'
new_pc_df['category'].value_counts()
# Out:
# category
# Memory & Storage                       2453
#                                        2363
# Accessories for Smartphones            1612
# Electronic Devices & Accessories       1273
# Computers & Laptops                    1054
# Accessories for Computers & Laptops     975
# Smartphones                             262
# Name: count, dtype: int64

# %%
new_pc_df.loc[
    (new_pc_df.loc[(new_pc_df['category'] == '') &
     (new_pc_df['name'].str.contains('airpod', case=False))]).index,
    'category'] = 'Accessories for Electronic Devices'
# Out:
# category
#                                        3845
# Memory & Storage                       2136
# Accessories for Smartphones            1527
# Computers & Laptops                    1054
# Accessories for Computers & Laptops     975
# Smartphones                             262
# Electronic Devices                      187
# Accessories for Electronic Devices        6
# Name: count, dtype: int64

# %%
new_pc_df.loc[new_pc_df['category'].isin(['Electronic Devices', 'Accessories for Electronic Devices']), 'category'] = 'Electronic Devices & Accessories'
new_pc_df['category'].value_counts()
# Out:
# category
#                                        3845
# Memory & Storage                       2136
# Accessories for Smartphones            1527
# Computers & Laptops                    1054
# Accessories for Computers & Laptops     975
# Smartphones                             262
# Electronic Devices & Accessories        193
# Name: count, dtype: int64

# %%
new_pc_df.loc[
    (new_pc_df.loc[(new_pc_df['category'] == '') &
     (new_pc_df['name'].str.contains('watch', case=False))]).index,
    'category'] = 'Electronic Devices & Accessories'

# %%
new_pc_df.loc[
    (new_pc_df.loc[(new_pc_df['category'] == '') &
     (new_pc_df['name'].str.contains('monitor', case=False))]).index,
    'category'] = 'Electronic Devices & Accessories'

# %%
new_pc_df.loc[
    (new_pc_df.loc[(new_pc_df['category'] == '') &
     (new_pc_df['sku'].str.contains('REP', case=False)) &
              (new_pc_df['name'].str.contains('iphone', case = False))]).index,
    'category'] = 'Accessories for Smartphones'

# %%
new_pc_df.loc[
    (new_pc_df.loc[(new_pc_df['category'] == '') &
     (new_pc_df['sku'].str.contains('REP', case=False)) &
              (new_pc_df['name'].str.contains('ipad', case = False))]).index,
    'category'] = 'Electronic Devices & Accessories'

# %%
new_pc_df.loc[(new_pc_df.loc[(new_pc_df['category'] == '') &
     (new_pc_df['sku'].str.contains('REP', case=False))
            ]).index,
    'category'] = 'Accessories for Smartphones'

# %%
new_pc_df.loc[
    (new_pc_df.loc[(new_pc_df['category'] == '') &
     (new_pc_df['name'].str.contains('headphone', case=False))]).index,
    'category'] = 'Electronic Devices & Accessories'

# %%
new_pc_df.loc[
    (new_pc_df.loc[(new_pc_df['category'] == '') & (new_pc_df['name'].str.contains('ssd', case = False))]).index,
    'category'] = 'Memory & Storage'

# %%
new_pc_df.loc[
    (new_pc_df.loc[(new_pc_df['category'] == '') & (new_pc_df['name'].str.contains('drive', case = False))]).index,
    'category'] = 'Memory & Storage'

# %%
new_pc_df.loc[(new_pc_df.loc[(new_pc_df['category'] == '') & (new_pc_df['name'].str.contains('ipad case', case = False)) | (new_pc_df['name'].str.contains('ipad sleeve', case = False))]).index,
'category'] = 'Electronic Devices & Accessories'

# %%
new_pc_df.loc[
    (new_pc_df.loc[(new_pc_df['category'] == '') &
     (new_pc_df['name'].str.contains('microphone', case = False))]).index,
    'category'] = 'Electronic Devices & Accessories'

# %%
new_pc_df.loc[
    (new_pc_df.loc[(new_pc_df['category'] == '') &
     (new_pc_df['name'].str.contains('camera', case = False))]).index,
    'category'] = 'Electronic Devices & Accessories'

# %%
new_pc_df.loc[
    (new_pc_df.loc[(new_pc_df['category'] == '') &
     (new_pc_df['name'].str.contains('speaker', case = False))]).index,
    'category'] = 'Electronic Devices & Accessories'

# %%
new_pc_df['category'].value_counts()
# Out:
# category
# Memory & Storage                       2453
#                                        2363
# Accessories for Smartphones            1612
# Electronic Devices & Accessories       1273
# Computers & Laptops                    1054
# Accessories for Computers & Laptops     975
# Smartphones                             262
# Name: count, dtype: int64

# %%
new_pc_df.loc[(7104, 7105), 'category'] = 'Electronic Devices & Accessories'

# %%
#new_pc_df['category'] == 'Electronic Devices & Accessories']
new_pc_df.loc[
    (new_pc_df.loc[new_pc_df['name'].str.contains('watch strap', case=False)]).index,
    'category'] = 'Accessories for Electronic Devices'

# %%
new_pc_df.loc[
    (new_pc_df.loc[new_pc_df['name'].str.contains('airpods', case=False)]).index,
    'category'] = 'Accessories for Electronic Devices'

# %%
new_pc_df.loc[
    (5484, 8984, 2074),
    'category'] = 'Electronic Devices'

# %%
apple_watch = new_pc_df.loc[(new_pc_df['name'].str.contains('watch', case=False)) & (new_pc_df['sku'].str.contains('ap', case=False))]
new_pc_df.loc[(apple_watch.loc[(apple_watch['name'].str.contains('charging', case=False))]).index, 'category'] = 'Accessories for Electronic Devices'

# %%
new_pc_df.loc[(apple_watch.loc[(apple_watch['name'].str.contains('strap', case=False))]).index, 'category'] = 'Electronic Devices'

# %%
new_pc_df.loc[(new_pc_df.loc[new_pc_df['category'] == 'Electronic Devices & Accessories'].nlargest(500, 'price')).index, 'category'] = 'Electronic Devices'

# %%
new_pc_df.loc[(new_pc_df.loc[
    (new_pc_df['category'] == 'Electronic Devices & Accessories') &
     (new_pc_df['name'].str.contains('case', case=False))]).index,
              'category'] = 'Accessories for Electronic Devices'

# %%
new_pc_df.loc[(new_pc_df.loc[(new_pc_df['category'] == 'Electronic Devices & Accessories') &
     (new_pc_df['name'].str.contains('strap', case=False))]).index,
              'category'] = 'Accessories for Electronic Devices'

# %%
new_pc_df.loc[(new_pc_df.loc[(new_pc_df['category'] == 'Electronic Devices & Accessories')&
     (new_pc_df['name'].str.contains('repair', case=False))]).index,
              'category'] = 'Accessories for Electronic Devices'

# %%
new_pc_df.loc[(new_pc_df.loc[(new_pc_df['category'] == 'Electronic Devices & Accessories')&
     (new_pc_df['name'].str.contains('camera', case=False)) &
              (new_pc_df['name'].str.contains('iphone', case=False))]).index,
              'category'] = 'Accessories for Smartphones'

# %%
new_pc_df.loc[(new_pc_df.loc[(new_pc_df['category'] == 'Electronic Devices & Accessories') &
     (new_pc_df['name'].str.contains('smartwatch', case=False))]).index,
              'category'] = 'Electronic Devices'

# %%
new_pc_df.loc[(new_pc_df.loc[(new_pc_df['category'] == 'Electronic Devices & Accessories') &
     (new_pc_df['name'].str.contains('bluetooth', case=False))]
     ).index,
              'category'] = 'Electronic Devices'

# %%
new_pc_df.loc[(
new_pc_df.loc[(new_pc_df['category'] == 'Accessories for Electronic Devices') &
     (new_pc_df['name'].str.contains('microphone', case=False))]
     ).index,
              'category'] = 'Electronic Devices'

# %%
new_pc_df.loc[(
new_pc_df.loc[(new_pc_df['category'] == 'Electronic Devices & Accessories') &
     (new_pc_df['name'].str.contains('headphone', case=False))]
                ).index,
              'category'] = 'Electronic Devices'

# %%
new_pc_df.loc[(
new_pc_df.loc[(new_pc_df['category'] == 'Electronic Devices & Accessories') &
     (new_pc_df['name'].str.contains('support', case=False))]
                ).index,
              'category'] = 'Accessories for Electronic Devices'

# %%
new_pc_df.loc[(
new_pc_df.loc[(new_pc_df['category'] == 'Electronic Devices & Accessories') &
     (new_pc_df['desc'].str.contains('watch', case=False)) &
              (new_pc_df['desc'].str.contains('protector', case=False))] ).index,
              'category'] = 'Accessories for Electronic Devices'

# %%
new_pc_df.loc[(
new_pc_df.loc[(new_pc_df['category'] == 'Electronic Devices & Accessories') &
     (new_pc_df['desc'].str.contains('watch', case=False))]).index,
              'category'] = 'Accessories for Electronic Devices'

# %%
new_pc_df.loc[(
    new_pc_df.loc[(new_pc_df['category'] == 'Electronic Devices & Accessories') &
     (new_pc_df['desc'].str.contains('bluetooth', case=False))]).index,
              'category'] = 'Electronic Devices'

# %%
new_pc_df.loc[(
new_pc_df.loc[(new_pc_df['category'] == 'Electronic Devices & Accessories')&
     (new_pc_df['desc'].str.contains('monitor', case=False))]).index,
              'category'] = 'Electronic Devices'

# %%
new_pc_df.loc[(
new_pc_df.loc[(new_pc_df['category'] == 'Electronic Devices & Accessories')&
     (new_pc_df['name'].str.contains('monitor', case=False))]).index,
              'category'] = 'Electronic Devices'

# %%
new_pc_df.loc[(new_pc_df['category'] == 'Electronic Devices & Accessories')]
# Out:
#             sku                                               name  \
# 71      SYN0047              Synology Pack 1 license for IP camera
# 72      SYN0048                 Synology Pack 4 IP camera licenses
# 129     DLK0008           D-Link DCS-932L Wireless IP Camera Cloud
# 130     DLK0009           D-Link DCS-942L Wireless IP Camera Cloud
# 483     DLK0050  D-Link DCS-5020L wireless surveillance camera ...
# 611     GRT0311           CinemaSeat Griffin iPad sleeve black Air
# 650     LOG0116                 Logitech Portable Speaker Z50 Gray
# 692     OTR0103     Grenade Grip Gopole EmpuÌ ± Adura GoPro camera
# 693     OTR0104  Xsories Big U-Shot GoPro Camera Extension 95cm...
# 694     OTR0107  Xsories 50cm extension U-Shot camera GoPro Silver
# 739     DEV0007  Devolo dLAN LiveCam Single IP Surveillance Cam...
# 1104    GOP0079  GoPro 3 modes (± empuÌ Adura the camera arm ex...
# 1183    HAR0013       Harman Kardon Esquire Portable Speaker White
# ...

# %%
new_pc_df.loc[(4250,4211,3534,2606,2158,2081,1993,1652,1200,1183,739,650,483,130,129), 'category'] = 'Electronic Devices'

# %%
new_pc_df.loc[new_pc_df['category'] == 'Electronic Devices & Accessories', 'category'] = 'Accessories for Electronic Devices'

# %%
new_pc_df['category'].value_counts()
# Out:
# category
# Memory & Storage                       2453
#                                        2363
# Accessories for Smartphones            1620
# Computers & Laptops                    1054
# Accessories for Computers & Laptops     975
# Electronic Devices                      920
# Accessories for Electronic Devices      345
# Smartphones                             262
# Name: count, dtype: int64

# %%
new_pc_df.loc[
    (new_pc_df.loc[
    (new_pc_df['category'] == '') &
    (new_pc_df['name'].str.contains('adapter', case=False)) &
    (new_pc_df['desc'].str.contains('iphone', case=False))
    ]).index,
    'category'] = 'Accessories for Smartphones'

# %%
new_pc_df.loc[
    (new_pc_df.loc[
    (new_pc_df['category'] == '') &
    (new_pc_df['name'].str.contains('adapter', case=False))]).index,
    'category'] = 'Accessories for Computers & Laptops'

# %%
new_pc_df.loc[
    (new_pc_df.loc[
    (new_pc_df['category'] == '') &
    (new_pc_df['name'].str.contains('support', case=False)) &
    (new_pc_df['desc'].str.contains('iphone', case=False))]).index,
    'category'] = 'Accessories for Smartphones'

# %%
new_pc_df.loc[
    (new_pc_df.loc[
    (new_pc_df['category'] == '') &
    (new_pc_df['name'].str.contains('support', case=False)) &
    (new_pc_df['desc'].str.contains('mac', case=False))]).index,
    'category'] = 'Accessories for Computers & Laptops'

# %%
new_pc_df.loc[
    (new_pc_df.loc[
    (new_pc_df['category'] == '') &
    (new_pc_df['desc'].str.contains('headphones', case=False))]).index,
    'category'] = 'Electronic Devices'

# %%
new_pc_df.loc[
    (new_pc_df.loc[
    (new_pc_df['category'] == '')&
    (new_pc_df['name'].str.contains('iphone case', case=False))]).index,
    'category'] = 'Accessories for Smartphones'

# %%
new_pc_df.loc[
    (new_pc_df.loc[
    (new_pc_df['category'] == '')&
    (new_pc_df['name'].str.contains('Pencil', case=False))]).index,
    'category'] = 'Accessories for Electronic Devices'

# %%
new_pc_df.loc[
    (new_pc_df.loc[
    (new_pc_df['category'] == '')&
    (new_pc_df['name'].str.contains('case', case=False))]).index,
    'category'] = 'Accessories for Electronic Devices'

# %%
new_pc_df.loc[
    (new_pc_df.loc[
    (new_pc_df['category'] == '')&
    (new_pc_df['name'].str.contains('ipad', case=False))]).index,
    'category'] = 'Accessories for Electronic Devices'

# %%
new_pc_df.loc[
    (new_pc_df.loc[
    (new_pc_df['category'] == '')&
    (new_pc_df['name'].str.contains('stand', case=False)) &
    (new_pc_df['desc'].str.contains('iphone', case=False))]).index,
    'category'] = 'Accessories for Smartphones'

# %%
new_pc_df.loc[(295,1454,9430), 'category'] = 'Accessories for Electronic Devices'

# %%
new_pc_df.loc[
    (new_pc_df.loc[
    (new_pc_df['category'] == '')&
    (new_pc_df['name'].str.contains('stand', case=False))]).index,
    'category'] = 'Accessories for Computers & Laptops'

# %%
new_pc_df.loc[(44,79), 'category'] = 'Accessories for Electronic Devices'

# %%
new_pc_df.loc[
    (new_pc_df.loc[
    (new_pc_df['category'] == '') &
    (new_pc_df['name'].str.contains('trackpad', case=False))]
     ).index,
    'category'] = 'Electronic Devices'

# %%
new_pc_df.loc[new_pc_df['name'].str.contains('pencil', case=False)]
# Out:
#             sku                                               name  \
# 1933    FIF0008              FiftyThree Pencil Pointer iPad Dorado
# 1940    FIF0009         FiftyThree Walnut Wood Pencil Pointer iPad
# 2069    AST0007                   Cleaning Spray pencil-astuce 6ml
# 2389    WAC0166  Wacom Intuos Graphics Tablet S Draw with penci...
# 3516    APP1221                                       Apple Pencil
# 3572  FIF0003-A  Open - FiftyThree Walnut Wood Pencil Pointer iPad
# 4999    BEL0266                Base for Apple Belkin Silver Pencil
# 5238    APP1809                     Apple Apple Pack 4 Pencil Tips
# 6109  WAC0160-A  Open - Wacom Intuos Graphics Tablet S Draw wit...
# 7089    AP20113                            Like new - Apple Pencil
# 7616    APP2159                       Apple Pencil Case brown Topo
# 7659    APP2181                      Candy Apple Brown Pencil Case
# 7660    APP2182                       Apple Pencil Case Blue Night
# ...

# %%
new_pc_df.loc[(7089, 3516), 'category'] = 'Electronic Devices'

# %%
new_pc_df.loc[
    (new_pc_df.loc[
    (new_pc_df['category'] == '') &
    (new_pc_df['name'].str.contains('hard disk', case = False))]).index,
    'category'] = 'Memory & Storage'

# %%
new_pc_df.loc[
    (new_pc_df.loc[
    (new_pc_df['category'] == '') &
    (new_pc_df['sku'].str.contains('wac', case = False))&
    (new_pc_df['name'].str.contains('pen', case = False))]).index,
    'category'] = 'Electronic Devices'

# %%
new_pc_df['category'].value_counts()
# Out:
# category
# Memory & Storage                       2632
# Accessories for Smartphones            1811
# Electronic Devices                     1295
# Accessories for Computers & Laptops    1246
# Computers & Laptops                    1054
# Accessories for Electronic Devices     1011
#                                         681
# Smartphones                             262
# Name: count, dtype: int64

# %%
new_pc_df.loc[
    (new_pc_df.loc[
    (new_pc_df['category'] == '') &
    (new_pc_df['desc'].str.contains('head', case = False))]).index,
    'category'] = 'Electronic Devices'

# %%
new_pc_df.loc[
    (new_pc_df.loc[
    (new_pc_df['category'] == '') &
    (new_pc_df['name'].str.contains('apple ipod', case = False))]).index,
    'category'] = 'Electronic Devices'

# %%
new_pc_df.loc[
    (new_pc_df.loc[
    (new_pc_df['category'] == '') &
    (new_pc_df['name'].str.contains('mac', case = False))]).index,
    'category'] = 'Accessories for Electronic Devices'

# %%
new_pc_df.loc[
    (new_pc_df.loc[
    (new_pc_df['category'] == '') &
    (new_pc_df['name'].str.contains('battery', case = False)) &
    (new_pc_df['name'].str.contains('iphone', case = False))]).index,
    'category'] = 'Accessories for Smartphones'

# %%
new_pc_df.loc[
    (new_pc_df.loc[
    (new_pc_df['category'] == '') &
    (new_pc_df['name'].str.contains('battery', case = False))]).index,
    'category'] = 'Accessories for Electronic Devices'

# %%
new_pc_df.loc[(4710, 4711), 'category'] = 'Accessories for Smartphones'

# %%
new_pc_df.loc[
    (new_pc_df.loc[
    (new_pc_df['category'] == '')&
    (new_pc_df['name'].str.contains('dock', case = False))]).index,
    'category'] = 'Accessories for Computers & Laptops'

# %%
new_pc_df.loc[
    (new_pc_df.loc[
    (new_pc_df['category'] == '')&
    (new_pc_df['name'].str.contains('printer', case = False))]).index,
    'category'] = 'Electronic Devices'

# %%
new_pc_df.loc[
    (new_pc_df.loc[
    (new_pc_df['category'] == '')&
    (new_pc_df['name'].str.contains('armband', case = False))]).index,
    'category'] = 'Accessories for Smartphones'

# %%
new_pc_df.loc[
    (new_pc_df.loc[
    (new_pc_df['category'] == '')&
    (new_pc_df['name'].str.contains('iphone', case = False))&
    (new_pc_df['name'].str.contains('kit', case = False))]).index,
    'category'] = 'Accessories for Smartphones'

# %%
new_pc_df.loc[
    (new_pc_df.loc[
    (new_pc_df['category'] == '')&
    (new_pc_df['name'].str.contains('iphone', case = False))]).index,
    'category'] = 'Accessories for Smartphones'

# %%
new_pc_df.loc[9746, 'category'] = 'Accessories for Smartphones'

# %%
new_pc_df.loc[
    (new_pc_df.loc[
    (new_pc_df['category'] == '')&
    (new_pc_df['name'].str.contains('tablet', case = False))]).index,
    'category'] = 'Electronic Devices'

# %%
new_pc_df.loc[
    (new_pc_df.loc[
    (new_pc_df['category'] == '')&
    (new_pc_df['name'].str.contains('hub', case = False))]).index,
    'category'] = 'Accessories for Computers & Laptops'

# %%
new_pc_df.loc[
    (new_pc_df.loc[
    (new_pc_df['category'] == '') &
    (new_pc_df['desc'].str.contains('smartwatch', case = False))]).index,
    'category'] = 'Electronic Devices'

# %%
new_pc_df.loc[586, 'category'] = 'Accessories for Electronic Devices'

# %%
new_pc_df.loc[
    (new_pc_df.loc[
    (new_pc_df['category'] == '') &
    (new_pc_df['name'].str.contains('apple tv', case = False))]).index,
    'category'] = 'Electronic Devices'

# %%
new_pc_df.loc[
    (new_pc_df.loc[
    (new_pc_df['category'] == '') &
    (new_pc_df['desc'].str.contains('strap', case = False))]).index,
    'category'] = 'Accessories for Electronic Devices'

# %%
new_pc_df.loc[
    (new_pc_df.loc[
    (new_pc_df['category'] == '') &
    (new_pc_df['name'].str.contains('fitbit', case = False))]).index,
    'category'] = 'Electronic Devices'

# %%
new_pc_df.loc[
    (new_pc_df.loc[
    (new_pc_df['category'] == '') &
    (new_pc_df['desc'].str.contains('monitor', case = False))].nlargest(15, 'price')).index,
    'category'] = 'Electronic Devices'

# %%
new_pc_df.loc[
    (new_pc_df.loc[
    (new_pc_df['category'] == '') &
    (new_pc_df['name'].str.contains('Thunder', case = False))]).index,
    'category'] = 'Memory & Storage'

# %%
new_pc_df.loc[
    (new_pc_df.loc[
    (new_pc_df['category'] == '') &
    (new_pc_df['name'].str.contains('gopro', case = False))].nlargest(2, 'price')).index,
    'category'] = 'Electronic Devices'

# %%
new_pc_df.loc[
    (new_pc_df.loc[
    (new_pc_df['category'] == '') &
    (new_pc_df['name'].str.contains('gopro', case = False))]).index,
    'category'] = 'Accessories for Electronic Devices'

# %%
new_pc_df.loc[
    (new_pc_df.loc[
    (new_pc_df['category'] == '') &
    (new_pc_df['name'].str.contains('synology DS', case = False))]).index,
    'category'] = 'Memory & Storage'

# %%
new_pc_df.loc[8136, 'category'] = 'Electronic Devices'

# %%
new_pc_df.loc[
    (new_pc_df.loc[
    (new_pc_df['category'] == '') &
    (new_pc_df['desc'].str.contains('tablet', case = False))]).index,
    'category'] = 'Electronic Devices'

# %%
new_pc_df.loc[
    (new_pc_df.loc[
    (new_pc_df['category'] == '') &
    (new_pc_df['name'].str.contains('TB', case = False))]).index,
    'category'] = 'Memory & Storage'

# %%
new_pc_df.loc[
    (new_pc_df.loc[
    (new_pc_df['category'] == '') &
    (new_pc_df['name'].str.contains('drone', case = False))]).index,
    'category'] = 'Electronic Devices'

# %%
new_pc_df.loc[
    (new_pc_df.loc[
    (new_pc_df['category'] == '') &
    (new_pc_df['sku'].str.contains('SNS', case = False))]).index,
    'category'] = 'Electronic Devices'

# %%
new_pc_df.loc[
    (new_pc_df.loc[
    (new_pc_df['category'] == '') &
    (new_pc_df['desc'].str.contains('router', case = False))]).index,
    'category'] = 'Electronic Devices'

# %%
new_pc_df.loc[(9628, 9814), 'category'] = 'Accessories for Electronic Devices'

# %%
new_pc_df.loc[
    (new_pc_df['category'] == '') &
    (new_pc_df['desc'].str.contains('iphone', case = False))]
# Out:
#             sku                                               name  \
# 58      MOS0065                    Moshi TeraGlove cleaner screens
# 59      WAC0032   Wacom Bamboo Stylus Pack 3 first generation tips
# 297     WAH0007      Wahoo Fitness BlueSC cadence and speed sensor
# 301     PAR0009              Parrot Minikit + bluetooth hands free
# 366     KEN0096  Kensington Evap Water Rescue Pouch bag wet sal...
# ...         ...                                                ...
# 9640  ELG0039-A                     Open - Elgato avea Sphere Lamp
# 9701  ADN0047-A            Open - Adonit Jot Dash 3 Pointer Silver
# 9703  ADN0051-A      Open - Adonit Jot Pro Stylus Pointer Blue 3.0
# 9822  MIN0005-A     Open - Minibatt iCharge Qi charger Fast charge
# 9828  HOC0012-A  Open - Hoco UltraSlim BateråÕa 10,000 mAh Exte...
#
#                                                    desc  price  in_stock  \
# 58    Microfibre screen cleaner for Mac iPhone iPad ...  20.00         0
# ...

# %%
new_pc_df['category'].value_counts(normalize=True)
# Out:
# category
# Memory & Storage                       0.263411
# Accessories for Smartphones            0.181245
# Electronic Devices                     0.129604
# Accessories for Computers & Laptops    0.124700
# Computers & Laptops                    0.105484
# Accessories for Electronic Devices     0.101181
#                                        0.068155
# Smartphones                            0.026221
# Name: proportion, dtype: float64

# %%
new_pc_df.loc[new_pc_df['category'] == '', 'category'] = 'Other'

# %%
new_pc_df
# Out:
#           sku                                           name  \
# 0     RAI0007              Silver Rain Design mStand Support
# 1     APP0023              Apple Mac Keyboard Keypad Spanish
# 2     APP0025               Mighty Mouse Apple Mouse for Mac
# 3     APP0072  Apple Dock to USB Cable iPhone and iPod white
# 4     KIN0007    Mac Memory Kingston 2GB 667MHz DDR2 SO-DIMM
# ...       ...                                            ...
# 9987  BEL0376        Belkin Travel Support Apple Watch Black
# 9988  THU0060   Enroute Thule 14L Backpack MacBook 13 "Black
# 9989  THU0061    Enroute Thule 14L Backpack MacBook 13 "Blue
# 9990  THU0062     Enroute Thule 14L Backpack MacBook 13 "Red
# 9991  THU0063   Enroute Thule 14L Backpack MacBook 13 "Green
#
#                                                    desc  price  in_stock  \
# 0          Aluminum support compatible with all MacBook  59.99         1
# 1             USB ultrathin keyboard Apple Mac Spanish.  59.00         0
# ...

# %% [markdown]
# ## Price category

# %%
def category_by_price(price):
    if price < 50:
        return 'low'
    elif 50 <= price < 200:
        return 'medium'
    else:
        return 'high'


products_cl['price_category'] = products_cl['price'].apply(category_by_price)
price_category = products_cl['price'].apply(category_by_price)
products_cl[['desc', 'price', 'price_category']].head(20)
# Out:
#                                                  desc  price price_category
# 0        Aluminum support compatible with all MacBook  59.99         medium
# 1           USB ultrathin keyboard Apple Mac Spanish.  59.00         medium
# 2                              mouse Apple USB cable.  59.00         medium
# 3               IPhone dock and USB Cable Apple iPod.  25.00            low
# 4   2GB RAM Mac mini and iMac (2006/07) MacBook Pr...  34.99            low
# 5   IPhone and iPod AV Cable Dock to Composite Video.  45.00            low
# 6   1GB RAM Mac mini and iMac (2006/07) MacBook Pr...  18.99            low
# 7        2GB RAM iMac with Intel Core 2 Duo (Penryn).  36.99            low
# 8   RAM 4GB (2x2GB) Mac mini and iMac (2006/07) Ma...  74.00         medium
# 9   Adapter Mini Display Port to VGA MacBook and M...  35.00            low
# 10  Adapter mini DisplayPort to DVI MacBook and Ma...  35.00            low
# ...

# %%
products_cl["price_category"].value_counts()
# Out:
# price_category
# high      4006
# low       3132
# medium    2854
# Name: count, dtype: int64

# %% [markdown]
# ## Brand

# %%
url = 'https://drive.google.com/file/d/1m1ThDDIYRTTii-rqM5SEQjJ8McidJskD/view?usp=sharing'
path = 'https://drive.google.com/uc?export=download&id='+url.split('/')[-2]
brand = pd.read_csv(path)

# %%
brand_df = brand.copy()

# %%
brand_df
# Out:
#     short       long
# 0     8MO  8Mobility
# 1     ACM       Acme
# 2     ADN     Adonit
# 3     AII      Aiino
# 4     AKI     Akitio
# ..    ...        ...
# 182   XOO     Xoopar
# 183   XRI     X-Rite
# 184   XTO      Xtorm
# 185   ZAG   ZaggKeys
# 186   ZEP       Zepp
#
# [187 rows x 2 columns]

# %%
new_pc_df['short'] = new_pc_df['sku'].str[:3]

# %%
new_pc_df = new_pc_df.merge(brand_df, on='short', how='left')

# %%
new_pc_df = new_pc_df.drop(['short'], axis=1)

# %%
new_pc_df.rename(columns={'long': 'brand'})
# Out:
#           sku                                           name  \
# 0     RAI0007              Silver Rain Design mStand Support
# 1     APP0023              Apple Mac Keyboard Keypad Spanish
# 2     APP0025               Mighty Mouse Apple Mouse for Mac
# 3     APP0072  Apple Dock to USB Cable iPhone and iPod white
# 4     KIN0007    Mac Memory Kingston 2GB 667MHz DDR2 SO-DIMM
# ...       ...                                            ...
# 9987  BEL0376        Belkin Travel Support Apple Watch Black
# 9988  THU0060   Enroute Thule 14L Backpack MacBook 13 "Black
# 9989  THU0061    Enroute Thule 14L Backpack MacBook 13 "Blue
# 9990  THU0062     Enroute Thule 14L Backpack MacBook 13 "Red
# 9991  THU0063   Enroute Thule 14L Backpack MacBook 13 "Green
#
#                                                    desc  price  in_stock  \
# 0          Aluminum support compatible with all MacBook  59.99         1
# 1             USB ultrathin keyboard Apple Mac Spanish.  59.00         0
# ...

# %%
#new_pc_df.to_csv('product_category.csv', index=False)

#from google.colab import files
#files.download('product_category.csv')
